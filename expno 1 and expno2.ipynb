# %%
import pandas as pd

# %%
df=pd.read_csv('videos.csv')

# %%
df
# Out:
#          video_id                                              title  \
# 0     XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1     K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
# 2     cLdxuaxaQwc                                        My Response
# 3     WYYvHb03Eog                          Apple iPhone X first look
# 4     sjlHnJvXdQs                                  iPhone X (parody)
# 5     cMKX2tE5Luk    The Disaster Artist | Official Trailer HD | A24
# 6     8wNr-NQImFg       The Check In: HUD, Ben Carson and Hurricanes
# 7     _HTXMhKWqnA                   iPhone X Impressions & Hands On!
# 8     _ANP3HR1jsM                         ATTACKED BY A POLICE DOG!!
# 9     zgLtEob6X-Q                 Honest Trailers - The Mummy (2017)
# 10    Ayb_2qbZHm4                                Honest College Tour
# 11    CsdzflTXBVQ  Best Floyd Mayweather Interview | Awkward Puppets
# 12    l864IBj7cgw  Jennifer Lawrence Challenges Jimmy to an Axe T...
# ...

# %%
df.shape
# Out:
# (7998, 21)

# %%
df.isnull().sum()
# Out:
# video_id             0
# title                0
# channel_title        0
# category_id          0
# tags                 0
# views                0
# likes                0
# dislikes             0
# comment_total        0
# thumbnail_link       0
# date                 0
# Unnamed: 11       7992
# Unnamed: 12       7996
# Unnamed: 13       7996
# Unnamed: 14       7996
# Unnamed: 15       7996
# Unnamed: 16       7996
# Unnamed: 17       7996
# Unnamed: 18       7996
# Unnamed: 19       7996
# Unnamed: 20       7996
# dtype: int64

# %%
filter= (df['channel_title']=='Logan Paul Vlogs')
df[filter]
# Out:
#          video_id                                              title  \
# 0     XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 204   XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 420   XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 682   XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 914   XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1146  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1388  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 6799  3y5A4paFOb4  Logan Paul - Outta My Hair [Official Music Video]
# 7012  3y5A4paFOb4  Logan Paul - Outta My Hair [Official Music Video]
# 7258  3y5A4paFOb4  Logan Paul - Outta My Hair [Official Music Video]
# 7500  3y5A4paFOb4  Logan Paul - Outta My Hair [Official Music Video]
# 7746  3y5A4paFOb4  Logan Paul - Outta My Hair [Official Music Video]
# 7969  3y5A4paFOb4  Logan Paul - Outta My Hair [Official Music Video]
#
# ...

# %%
var1=(df['channel_title']=='MoorInfo')
df.loc[var1,['likes', 'dislikes', 'views']]
# Out:
#       likes  dislikes   views
# 459    2432       295  129102
# 686    2577       334  142583
# 929    2615       355  145407
# 1148   2621       360  146466
# 1389   2626       364  146963

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Laptop\\Desktop\\Data Analytics Youtube'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Laptop\\Desktop\\Data Analytics Youtube'

# %%
os.path.exists("videos.csv")
# Out:
# True

# %%
import pandas as pd
data=pd.read_csv('videos.csv')
data
# Out:
#          video_id                                              title  \
# 0     XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1     K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
# 2     cLdxuaxaQwc                                        My Response
# 3     WYYvHb03Eog                          Apple iPhone X first look
# 4     sjlHnJvXdQs                                  iPhone X (parody)
# 5     cMKX2tE5Luk    The Disaster Artist | Official Trailer HD | A24
# 6     8wNr-NQImFg       The Check In: HUD, Ben Carson and Hurricanes
# 7     _HTXMhKWqnA                   iPhone X Impressions & Hands On!
# 8     _ANP3HR1jsM                         ATTACKED BY A POLICE DOG!!
# 9     zgLtEob6X-Q                 Honest Trailers - The Mummy (2017)
# 10    Ayb_2qbZHm4                                Honest College Tour
# 11    CsdzflTXBVQ  Best Floyd Mayweather Interview | Awkward Puppets
# 12    l864IBj7cgw  Jennifer Lawrence Challenges Jimmy to an Axe T...
# ...

# %%
df.head(10)
# Out:
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
# 2  cLdxuaxaQwc                                        My Response
# 3  WYYvHb03Eog                          Apple iPhone X first look
# 4  sjlHnJvXdQs                                  iPhone X (parody)
# 5  cMKX2tE5Luk    The Disaster Artist | Official Trailer HD | A24
# 6  8wNr-NQImFg       The Check In: HUD, Ben Carson and Hurricanes
# 7  _HTXMhKWqnA                   iPhone X Impressions & Hands On!
# 8  _ANP3HR1jsM                         ATTACKED BY A POLICE DOG!!
# 9  zgLtEob6X-Q                 Honest Trailers - The Mummy (2017)
#
#                  channel_title  category_id  \
# 0             Logan Paul Vlogs           24
# 1                        Apple           28
# 2                    PewDiePie           22
# 3                    The Verge           28
# ...

# %%
df.tail(6)
# Out:
#          video_id                                              title  \
# 7992  4kmSATD25iY                     Pumpkin Spice Oreo Taste Test!
# 7993  xlu6i6lT_vk                     How Do MASSIVE Sinkholes Form?
# 7994  qRoVlH1OcI4  Trump slams Clinton for defending NFL anthem p...
# 7995  EoejGgUNmVU  LP - Lost On You (A Night at The McKittrick Ho...
# 7996  MT1CMTI0EVw  Tré Melvin @ #YouTubeBlack FanFest Washington ...
# 7997  AFxLA3RGjnc  First cosmic event seen in gravitational waves...
#
#                     channel_title  category_id  \
# 7992                     iJustine           22
# 7993                  Life Noggin           27
# 7994             Business Insider           25
# 7995                           LP           10
# 7996              YouTube FanFest           24
# 7997  National Science Foundation           28
#
#                                                    tags   views  likes  \
# 7992  ijustine|pumpkin spice oreo|taste test|itsmeje...  164625   6688
# ...

# %%
# Out:
# (7998, 21)

# %%
# Out:
# (7998, 21)

# %%
 
data1 = list(data["likes"])
print(data1)
# Out:
# [320053, 185853, 576597, 24975, 96666, 34507, 9985, 74062, 69687, 29943, 34485, 28050, 8085, 9215, 14740, 18936, 14870, 65749, 23945, 7941, 66420, 1521, 2921, 21817, 3498, 6126, 384920, 16258, 65730, 15424, 42290, 19575, 6218, 9143, 25456, 39791, 71, 490, 15314, 3712, 9531, 19183, 2070, 9889, 26521, 74587, 4389, 1069, 12179, 1692, 19538, 345, 3553, 61409, 38823, 2123, 3752, 14096, 119, 4165, 141, 9467, 70, 139, 104899, 17517, 3858, 520, 13901, 
864IBj7cgw  Jennifer Lawrence Challenges Jimmy to an Axe T...
# ...

# %%
views=pd.Series(df.views)

# %%
print(views.sort_values())
# Out:
# 7455           0
# 7932           0
# 4754           0
# 6998           0
# 5196           0
# 4500           0
# 7207           0
# 4968           0
# 4869           0
# 7705           0
# 5351         468
# 5459         559
# 4782         706
# 5703         710
# 5948         755
# 4257         933
# 121         1002
# 364         1097
# 4792        1098
# 799         1243
# 7955        1280
# 2719        1341
# 3057        1410
# 7321        1445
# 3654        1541
# 7563        1597
# 7066        1687
# 157         1712
# 2196        1731
# 397         1749
#           ...
# 5629    15880851
# 1015    15906520
# 4355    15952413
# 7746    16919441
# 5880    17603320
# 674     18082737
# 5798    18150878
# 6141    18497518
# 7969    18809766
# 6374    19194567
# 5599    19314234
# 1258    19496639
# 905     19707391
# 1203    20565649
# 1518    22787997
# 5802    23802798
# 5998    24786774
# 6030    26208268
# 1783    27750173
# 6274    27909589
# 6210    28212358
# ...

# %%
print(views.max())
# Out:
# 41500672

# %%
print(views.min())
# Out:
# 0

# %%
views.plot(kind='line')

# %%
likes=pd.Series(df.likes)
likes
# Out:
# 0        320053
# 1        185853
# 2        576597
# 3         24975
# 4         96666
# 5         34507
# 6          9985
# 7         74062
# 8         69687
# 9         29943
# 10        34485
# 11        28050
# 12         8085
# 13         9215
# 14        14740
# 15        18936
# 16        14870
# 17        65749
# 18        23945
# 19         7941
# 20        66420
# 21         1521
# 22         2921
# 23        21817
# 24         3498
# 25         6126
# 26       384920
# 27        16258
# 28        65730
# 29        15424
#          ...
# 7968        514
# 7969    1075133
# 7970      11262
# 7971        116
# 7972        217
# 7973       3048
# 7974      73813
# 7975       8694
# 7976        936
# 7977       5728
# 7978         93
# 7979       6401
# 7980       2139
# 7981        500
# 7982       8700
# 7983      21909
# 7984      17145
# 7985      67484
# 7986       2434
# 7987        189
# 7988     132302
# 7989        376
# 7990        305
# 7991      18242
# ...

# %%
likes.plot(kind='box',title='likes')
print(likes.quantile(.25))
# Out:
# 1901.5

# %%
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Laptop\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
import matplotlib.pyplot as plt
plt.xlabel('views')
plt.hist(views,range(24975,100000))
# Out:
# (array([0., 0., 0., ..., 0., 0., 0.]),
#  array([24975, 24976, 24977, ..., 99997, 99998, 99999]),
#  <a list of 75024 Patch objects>)

# %%
views.plot(kind='hist')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('videos.csv')
df
# Out:
#          video_id                                              title  \
# 0     XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1     K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
# 2     cLdxuaxaQwc                                        My Response
# 3     WYYvHb03Eog                          Apple iPhone X first look
# 4     sjlHnJvXdQs                                  iPhone X (parody)
# 5     cMKX2tE5Luk    The Disaster Artist | Official Trailer HD | A24
# 6     8wNr-NQImFg       The Check In: HUD, Ben Carson and Hurricanes
# 7     _HTXMhKWqnA                   iPhone X Impressions & Hands On!
# 8     _ANP3HR1jsM                         ATTACKED BY A POLICE DOG!!
# 9     zgLtEob6X-Q                 Honest Trailers - The Mummy (2017)
# 10    Ayb_2qbZHm4                                Honest College Tour
# 11    CsdzflTXBVQ  Best Floyd Mayweather Interview | Awkward Puppets
# 12    l864IBj7cgw  Jennifer Lawrence Challenges Jimmy to an Axe T...
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('videos.csv')
dataset
# Out:
#          video_id                                              title  \
# 0     XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1     K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
# 2     cLdxuaxaQwc                                        My Response
# 3     WYYvHb03Eog                          Apple iPhone X first look
# 4     sjlHnJvXdQs                                  iPhone X (parody)
# 5     cMKX2tE5Luk    The Disaster Artist | Official Trailer HD | A24
# 6     8wNr-NQImFg       The Check In: HUD, Ben Carson and Hurricanes
# 7     _HTXMhKWqnA                   iPhone X Impressions & Hands On!
# 8     _ANP3HR1jsM                         ATTACKED BY A POLICE DOG!!
# 9     zgLtEob6X-Q                 Honest Trailers - The Mummy (2017)
# 10    Ayb_2qbZHm4                                Honest College Tour
# 11    CsdzflTXBVQ  Best Floyd Mayweather Interview | Awkward Puppets
# 12    l864IBj7cgw  Jennifer Lawrence Challenges Jimmy to an Axe T...
# ...

# %%
dataset['dislikes'].plot(kind='hist')

# %%
plt.xlabel('views')
plt.ylabel('likes')
plt.scatter(views,likes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b450d5211fe0> in <module>
#       1 plt.xlabel('views')
#       2 plt.ylabel('likes')
# ----> 3 plt.scatter(views,likes)
#
# NameError: name 'views' is not defined

# %%
import matplotlib.pyplot as plt
